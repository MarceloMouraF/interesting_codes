# %% [markdown]
# <a href="https://colab.research.google.com/github/MarceloMouraF/interesting_codes/blob/main/Pontos_Para_Laudo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Notebook ArcPy criado através do model builder**

# %%
# -*- coding: utf-8 -*-
## Basta criar um ModelBuilder e exportar o modelo depois de ter setado tudo

# Alguns caminhos foram modificados
"""
Generated by ArcGIS ModelBuilder on : 2023-09-19 10:52:49
"""
import arcpy

def Model4():  # Model4

    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = True

    arcpy.ImportToolbox(r"c:\program files\arcgis\pro\Resources\ArcToolbox\toolboxes\Analysis Tools.tbx")
    XX_Aprovados_Diss_Cult_v2 = "XX_Aprovados_Diss_Cult_v2"
    Shapes_Separados_2_ = "D:\\XX\\05_Clientes\\03_TESTE\\\\20230919\\Shapes_Separados_Python"

    # Process: Split By Attributes (Split By Attributes) (analysis)
    Shapes_Separados = arcpy.analysis.SplitByAttributes(Input_Table=XX_Aprovados_Diss_Cult_v2, Target_Workspace=Shapes_Separados_2_, Split_Fields=["s_prod"])[0]

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace=r"D:\XX\04_LAUDOS\02_Jaime\LAUDOS_STD_PILOTO_2.gdb", workspace=r"D:\XX\04_LAUDOS\02_Jaime\LAUDOS_STD_PILOTO_2.gdb"):
        Model4()

# %%
# -*- coding: utf-8 -*-
"""
Generated by ArcGIS ModelBuilder on : 2023-09-19 11:36:27
"""
import arcpy
import os

from sys import argv
def FeatureClassGenerator(workspace, wild_card, feature_type, recursive) :
  with arcpy.EnvManager(workspace = workspace):

    dataset_list = [""]
    if recursive:
      datasets = arcpy.ListDatasets()
      dataset_list.extend(datasets)

    for dataset in dataset_list:
      featureclasses = arcpy.ListFeatureClasses(wild_card, feature_type, dataset)
      for fc in featureclasses:
        yield os.path.join(workspace, dataset, fc), fc


def Model6(Split_Line_Name_shp, Points_Name_shp):
    # To allow overwriting outputs change overwriteOutput option to True.
    arcpy.env.overwriteOutput = False

    arcpy.ImportToolbox(r"c:\program files\arcgis\pro\Resources\ArcToolbox\toolboxes\Data Management Tools.tbx")
    Shapes_Separados_Python = "D:\\05_BACEN\\05_Clientes\\03_TESTE\\20230919\\Shapes_Separados_Python"

    for Alexandre_Grendene_shp, Name in FeatureClassGenerator(Shapes_Separados_Python, "", "POLYGON", "RECURSIVE"):
        # Extrair o nome do shapefile sem a extensão
        Name = os.path.splitext(os.path.basename(Alexandre_Grendene_shp))[0]

        # Construir os nomes dos arquivos de saída com base no nome do shape de origem
        Split_Line_Name_shp = fr"D:\05_BACEN\05_Clientes\03_TESTE\20230919\Process_Pontos_Python\Linhas\Split_Line_{Name}.shp"
        Points_Name_shp = fr"D:\05_BACEN\05_Clientes\03_TESTE\20230919\Process_Pontos_Python\Pontos\Points_{Name}.shp"

        # Process: Split Line At Vertices (Split Line At Vertices) (management)
        arcpy.management.SplitLine(in_features=Alexandre_Grendene_shp, out_feature_class=Split_Line_Name_shp)

        # Process: Feature Vertices To Points (Feature Vertices To Points) (management)
        arcpy.management.FeatureVerticesToPoints(in_features=Split_Line_Name_shp, out_feature_class=Points_Name_shp, point_location="ALL")

        # Process: Delete Field (Delete Field) (management)
        Points_Name_shp_5_ = arcpy.management.DeleteField(in_table=Points_Name_shp, drop_field=["ID_VEGA", "s_ident", "s_ref", "s_prod", "s_doc", "s_cult", "s_area", "s_iplan", "s_fplan", "s_icol", "s_fcol", "s_idgleba", "s_nmgleba", "ID_Gleba", "Desc_gleba", "Localizaca", "N_talhoes", "Area_Gleba", "Produt_Obs", "ID_talhao", "Data_plant", "Cultura", "Desv_Veg", "Zarc", "Desenv_Lav", "Img", "Area_culti", "Data_IMG", "Obs", "IMAGEM", "ID_VEGAC", "AP", "cult", "Laudo_Gleb", "Laudo", "area_tal", "ORIG_FID"], method="DELETE_FIELDS")[0]

        # Process: Calculate Field (Calculate Field) (management)
        Points_Name_shp_3_ = arcpy.management.CalculateField(in_table=Points_Name_shp_5_, field="Ponto", expression="SequentialNumber()", expression_type="PYTHON3", code_block="""# Calculates a sequential number
# More calculator examples at esriurl.com/CalculatorExamples
rec=0
def SequentialNumber():
    global rec
    pStart = 1
    pInterval = 1
    if (rec == 0):
        rec = pStart
    else:
        rec = rec + pInterval
    return rec""", field_type="TEXT", enforce_domains="NO_ENFORCE_DOMAINS")[0]

        # Process: Calculate Geometry Attributes (Calculate Geometry Attributes) (management)
        Points_Name_shp_2_ = arcpy.management.CalculateGeometryAttributes(in_features=Points_Name_shp_3_, geometry_property=[["Longitude", "POINT_X"], ["Latitude", "POINT_Y"]], length_unit="", area_unit="", coordinate_system="GEOGCS[\"GCS_SIRGAS_2000\",DATUM[\"D_SIRGAS_2000\",SPHEROID[\"GRS_1980\",6378137.0,298.257222101]],PRIMEM[\"Greenwich\",0.0],UNIT[\"Degree\",0.0174532925199433]]", coordinate_format="DD")[0]

if __name__ == '__main__':
    # Global Environment settings
    with arcpy.EnvManager(scratchWorkspace=r"D:\XX\04_LAUDOS\02_Jaime\LAUDOS_STD_PILOTO_2.gdb", workspace=r"D:\XX\04_LAUDOS\02_Jaime\LAUDOS_STD_PILOTO_2.gdb"):
        Model6(None, None)  # Você pode passar None para os argumentos, pois eles serão definidos dentro do loop.
